# %%
import os
from dotenv import load_dotenv
from google import genai
from pydantic import BaseModel, Field
from typing import Literal
from auditLogger import logEvent
# Out:
# E:\1.ARCHIVIO GIACOMO\UNIVERSITA'\MAGISTRALE 1' ANNO\2 SEMESTRE\SoSe\Service-oriented-Software-Engineering\venv\lib\site-packages\google\auth\__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# E:\1.ARCHIVIO GIACOMO\UNIVERSITA'\MAGISTRALE 1' ANNO\2 SEMESTRE\SoSe\Service-oriented-Software-Engineering\venv\lib\site-packages\google\oauth2\__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)

# %%
class Env:
    _instance = None
    token = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super(Env, cls).__new__(cls)
            load_dotenv()
            cls.token = os.getenv('GEMINI_TOKEN')
        return cls._instance

# %%
env = Env()
geminiToken = env.token

print(geminiToken)

if not geminiToken:
    logEvent("API token not found. Please check your .env file.")
    raise ValueError("API token not found. Please check your .env file.")


client = genai.Client(api_key=geminiToken)
# Out:
# AIzaSyCSqt8o1SjrLQ2BaQNNXXJU-h0_1r9vJIc
